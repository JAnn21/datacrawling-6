# %%
import pandas as pd

df1_raw = pd.read_excel('./data/성북구_행정동별_생활인구수.xlsx')
df1 = df1_raw
df1
# Out:
#    시도명 시군구명  행정동명        총생활인구수
# 0   서울  성북구   종암동  38304.584250
# 1   서울  성북구  길음1동  34494.712847
# 2   서울  성북구   석관동  27202.226637
# 3   서울  성북구   안암동  25643.627395
# 4   서울  성북구   동선동  25587.965880
# 5   서울  성북구   삼선동  25189.335907
# 6   서울  성북구  월곡2동  24273.469336
# 7   서울  성북구  월곡1동  22227.288208
# 8   서울  성북구   성북동  21543.828802
# 9   서울  성북구  장위1동  21511.164936
# 10  서울  성북구  정릉2동  19441.273793
# 11  서울  성북구  정릉4동  18364.513253
# 12  서울  성북구  길음2동  16170.744675
# 13  서울  성북구   보문동  16020.023396
# 14  서울  성북구  정릉3동  15403.835711
# 15  서울  성북구  돈암2동  14351.636867
# 16  서울  성북구  정릉1동  14080.037778
# 17  서울  성북구  돈암1동  13131.225469
# 18  서울  성북구  장위2동  11570.072251
# 19  서울  성북구  장위3동   6299.887624

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "./data/malgun.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

plt.figure(figsize = (10, 5))
plt.rc('font', size=15, family=font)
plt.title('성북구 행정동별 하루평균 생활인구 상위 10개 동')
plt.bar(df_top10['행정동명'], df_top10['총생활인구수'])
plt.show()
